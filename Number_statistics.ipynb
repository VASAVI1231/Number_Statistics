# %% [markdown]
# <a href="https://colab.research.google.com/github/VASAVI1231/Number_Statistics/blob/main/Number_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# NUMBER STATISTICS PROJECT

# Create a list of numbers
numbers = [12, 7, 3, 18, 5, 20, 9]

# Create empty lists
even_numbers = []
odd_numbers = []

# Process each number
for number in numbers:

    if number % 2 == 0:
        even_numbers.append(number)

    else:
        odd_numbers.append(number)

# Find the largest and smallest numbers
largest_number = max(numbers)
smallest_number = min(numbers)

# Display the final results only once
print("NUMBER STATISTICS")
print("-----------------")

print("Original Numbers:", numbers)

print("Even Numbers:", even_numbers)

print("Odd Numbers:", odd_numbers)

print("Largest Number:", largest_number)

print("Smallest Number:", smallest_number)
# Out:
# NUMBER STATISTICS
# -----------------
# Original Numbers: [12, 7, 3, 18, 5, 20, 9]
# Even Numbers: [12, 18, 20]
# Odd Numbers: [7, 3, 5, 9]
# Largest Number: 20
# Smallest Number: 3
